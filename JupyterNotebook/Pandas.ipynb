# %%
import pandas
import json

# %%
dir(pandas) #Remember that dir(<object>) will return a list of callable things VERY USEFUL!
# Out:
# ['Categorical',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'ExcelFile',
#  'ExcelWriter',
#  'Expr',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int64Index',
#  'Interval',
#  'IntervalIndex',
#  'MultiIndex',
#  'NaT',
#  'Panel',
#  'Panel4D',
#  'Period',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseList',
#  'SparseSeries',
#  'Term',
#  'TimeGrouper',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt64Index',
#  'WidePanel',
#  '_DeprecatedModule',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_hashtable',
#  '_lib',
#  '_libs',
#  '_np_version_under1p10',
#  '_np_version_under1p11',
#  '_np_version_under1p12',
#  '_np_version_under1p13',
#  '_np_version_under1p14',
#  '_np_version_under1p8',
# ...

# %%
help(pandas.read_csv) #another VERY useful python built in function for displaying information about any <object>!
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# ...

# %%
with open("E:\\Code\\MiscData\\supermarkets.csv") as f:
    for line in f.readlines():
        print(line)
# Out:
# ID,Address,City,State,Country,Name,Employees
#
# 1,3666 21st St,San Francisco,CA 94114,USA,Madeira,8
#
# 2,735 Dolores St,San Francisco,CA 94119,USA,Bready Shop,15
#
# 3,332 Hill St,San Francisco,California 94114,USA,Super River,25
#
# 4,3995 23rd St,San Francisco,CA 94114,USA,Ben's Shop,10
#
# 5,1056 Sanchez St,San Francisco,California,USA,Sanchez,12
#
# 6,551 Alvarado St,San Francisco,CA 94114,USA,Richvalley,20

# %%
df=pandas.read_csv("E:\\Code\\MiscData\\supermarkets.csv") #Read a .csv file with pandas
#Sets the first line as the column headers
#in above function call pass header=None for no column headers
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pandas.read_excel("E:\\Code\\MiscData\\supermarkets.xlsx") #Read excel .xlsx files
df2
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
json.load(open("E:\\Code\\MiscData\\supermarkets.json")) #sample json data
# Out:
# [{'Address': '3666 21st St',
#   'City': 'San Francisco',
#   'Country': 'USA',
#   'Employees': 8,
#   'ID': 1,
#   'Name': 'Madeira',
#   'State': 'CA 94114'},
#  {'Address': '735 Dolores St',
#   'City': 'San Francisco',
#   'Country': 'USA',
#   'Employees': 15,
#   'ID': 2,
#   'Name': 'Bready Shop',
#   'State': 'CA 94119'},
#  {'Address': '332 Hill St',
#   'City': 'San Francisco',
#   'Country': 'USA',
#   'Employees': 25,
#   'ID': 3,
#   'Name': 'Super River',
#   'State': 'California 94114'},
#  {'Address': '3995 23rd St',
#   'City': 'San Francisco',
#   'Country': 'USA',
#   'Employees': 10,
#   'ID': 4,
#   'Name': "Ben's Shop",
#   'State': 'CA 94114'},
#  {'Address': '1056 Sanchez St',
#   'City': 'San Francisco',
#   'Country': 'USA',
#   'Employees': 12,
#   'ID': 5,
#   'Name': 'Sanchez',
#   'State': 'California'},
#  {'Address': '551 Alvarado St',
#   'City': 'San Francisco',
#   'Country': 'USA',
#   'Employees': 20,
#   'ID': 6,
#   'Name': 'Richvalley',
# ...

# %%
df3 = pandas.read_json("E:\\Code\\MiscData\\supermarkets.json") #Read .json files into a DataFrame
df3
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
dir(df3)
# Out:
# ['Address',
#  'City',
#  'Country',
#  'Employees',
#  'ID',
#  'Name',
#  'State',
#  'T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
df3.Name.sum().split(' ') #add all name values together then turn into a list
# Out:
# ['MadeiraBready', 'ShopSuper', "RiverBen's", 'ShopSanchezRichvalley']

# %%
df3.Employees.mean() #calculates the average
# Out:
# 15.0

# %%
df3 #manipulating df3 dataframe
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df3.set_index("ID") #change the indexing to be equal to the values of a given column
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
df3.loc["1":"3", "City":"Name"] #take index 1 - 3 (recall index is now the ID values)
                                #and from those indexes return the City - Name columns
# Out:
#             City Country  Employees  ID         Name
# 1  San Francisco     USA         15   2  Bready Shop
# 2  San Francisco     USA         25   3  Super River
# 3  San Francisco     USA         10   4   Ben's Shop

# %%
df3.loc[:,"Name":"State"] #return all names and states
# Out:
#           Name             State
# 0      Madeira          CA 94114
# 1  Bready Shop          CA 94119
# 2  Super River  California 94114
# 3   Ben's Shop          CA 94114
# 4      Sanchez        California
# 5   Richvalley          CA 94114

# %%
#return data based on indexes with iloc
df3.iloc[0:2, 1:3]
# Out:
#             City Country
# 0  San Francisco     USA
# 1  San Francisco     USA

# %%
df3.loc[3,"Name"] #return index 3 column name "Name" value
# Out:
# "Ben's Shop"

# %%
df3
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
#Dropping columns
df3.drop("Country",1)  #pass 1 to tell pandas you are removing a column
# Out:
#            Address           City  Employees  ID         Name  \
# 0     3666 21st St  San Francisco          8   1      Madeira
# 1   735 Dolores St  San Francisco         15   2  Bready Shop
# 2      332 Hill St  San Francisco         25   3  Super River
# 3     3995 23rd St  San Francisco         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco         12   5      Sanchez
# 5  551 Alvarado St  San Francisco         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
#Dropping Rows
df3.drop(5,0) #remove the 5th index row, 0 tells pandas we are dropping a row
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California

# %%
#Drop multiple rows
df3.drop(df3.index[0:2],0)
# Out:
#            Address           City Country  Employees  ID         Name  \
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df3["Address"]
# Out:
# 0       3666 21st St
# 1     735 Dolores St
# 2        332 Hill St
# 3       3995 23rd St
# 4    1056 Sanchez St
# 5    551 Alvarado St
# Name: Address, dtype: object

# %%
#Adding a column
#to add a column you can add a list to the dataframe dictionary, but the list me be the same length as the number of rows

df3["Continent"] = df3.shape[0] * ["North America"]

#df3.shape return a tuple(row, column) so we multiply our list by the number of rows
df3
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State      Continent
# 0          CA 94114  North America
# 1          CA 94119  North America
# 2  California 94114  North America
# 3          CA 94114  North America
# 4        California  North America
# 5          CA 94114  North America

# %%
#set the continent column to the Country column plus 'North America'
df3["Continent"] = df3["Country"] + ", " + "North America"
df3
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State           Continent
# 0          CA 94114  USA, North America
# 1          CA 94119  USA, North America
# 2  California 94114  USA, North America
# 3          CA 94114  USA, North America
# 4        California  USA, North America
# 5          CA 94114  USA, North America

# %%
#appending rows with another dataframe
#Note: make sure the data param is a list of lists.
dfTemp = pandas.DataFrame([["My Address", "My City", "My Country", 10, 10, "My Name", "My State", "My Continent"]],
                         columns=df3.keys())
dfTemp
# Out:
#       Address     City     Country  Employees  ID     Name     State  \
# 0  My Address  My City  My Country         10  10  My Name  My State
#
#       Continent
# 0  My Continent

# %%
#append the dataframe to the df3 data frame and update its index values
df3.append(dfTemp, ignore_index=True)
# Out:
#            Address           City     Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco         USA          8   1      Madeira
# 1   735 Dolores St  San Francisco         USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco         USA         25   3  Super River
# 3     3995 23rd St  San Francisco         USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco         USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco         USA         20   6   Richvalley
# 6       My Address        My City  My Country         10  10      My Name
#
#               State           Continent
# 0          CA 94114  USA, North America
# 1          CA 94119  USA, North America
# 2  California 94114  USA, North America
# 3          CA 94114  USA, North America
# 4        California  USA, North America
# 5          CA 94114  USA, North America
# 6          My State        My Continent
